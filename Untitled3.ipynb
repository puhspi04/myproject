# %% [markdown]
# <a href="https://colab.research.google.com/github/puhspi04/myproject/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3986051f-3117-485b-bd02-9753b88282d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3986051f-3117-485b-bd02-9753b88282d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip "archive (1).zip"
# Out:
# Archive:  archive (1).zip
# replace Main Dataset/BOTTLE/BOTTLE (1).png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Main Dataset/BOTTLE/BOTTLE (1).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (1).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (10).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (10).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (100).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (100).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (102).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (102).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (106).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (106).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (109).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (109).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (110).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (110).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (117).png
#   inflating: Main Dataset/BOTTLE/BOTTLE (117).xml
#   inflating: Main Dataset/BOTTLE/BOTTLE (12).png
# ...

# %%
# !pip install torch torchvision

# %%
import torch
import torchvision.models as models

model = models.resnet50(pretrained=True)

# change final layer
model.fc = torch.nn.Linear(model.fc.in_features, 6)

# %%
import torch
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim

# %%
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor()
])

# %%
dataset = datasets.ImageFolder("Main Dataset", transform=transform)

train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'Main Dataset',
#  'archive.zip',
#  'archive (1) (1).zip',
#  'archive (1).zip',
#  'solid_waste',
#  'sample_data']

# %%
model.fc = nn.Linear(model.fc.in_features, 6)

# %%
print(dataset.classes)
print(len(dataset))
# Out:
# ['BOTTLE', 'CAN', 'JUICE_BOX', 'MILK_CARTON', 'STYROFOAM', 'UTENSIL']
# 1558

# %%
model = models.resnet50(pretrained=True)

# change final layer
model.fc = nn.Linear(model.fc.in_features, 6)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
num_classes = len(dataset.classes)
model.fc = nn.Linear(model.fc.in_features, num_classes)

# %%
for epoch in range(5):

    running_loss = 0

    for images, labels in train_loader:

        optimizer.zero_grad()

        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        running_loss += loss.item()

    print("Epoch:", epoch+1, "Loss:", running_loss)
# Out:
# Epoch: 1 Loss: 36.48627880215645
# Epoch: 2 Loss: 23.268691509962082
# Epoch: 3 Loss: 17.359775982797146
# Epoch: 4 Loss: 14.434266023337841
# Epoch: 5 Loss: 13.297510243952274

# %%
correct = 0
total = 0

with torch.no_grad():
    for images, labels in train_loader:

        outputs = model(images)

        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)

        correct += (predicted == labels).sum().item()

print("Accuracy:", 100 * correct / total)
# Out:
# Accuracy: 92.49037227214377
